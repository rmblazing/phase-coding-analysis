# %%
import pickle as pkl
import numpy as np
import scipy
import matplotlib.pyplot as plt
import os
import phase_analysis
import preprocess_phase_data
import PGanalysis

# %%
def preprocess_spiking_data(expt_ID, datafile, mtrigger_file, expt_metadata_path, expt_category = 'contra', expt_type = 0):
    
    raster_save_path = r'Z:\robin\Paper\phase_coding_manuscript\data\fig2\raster_data'
    psth_save_path = r'Z:\robin\Paper\phase_coding_manuscript\data\fig2\psth_data'
        
    raster_path = os.path.join(raster_save_path, expt_category, expt_ID + '.npy')
    psth_path = os.path.join(psth_save_path, expt_category, expt_ID + '.npy')
    preprocess_phase_data.save_phase_raster_psth(raster_path, psth_path, datafile, mtrigger_file, expt_metadata_path, expt_type = expt_type)

# %%
def preprocess_resp(expt_ID, resp_file):

    resp_phase_save_path = r'Z:\robin\Paper\phase_coding_manuscript\data\fig2\resp_data'
    
    resp_path = os.path.join(resp_phase_save_path, expt_ID + '.npy')
    resp_array, instantaneous_phase_corrected = preprocess_phase_data.save_instantaneous_phase(resp_path, resp_file)
    
    return resp_array, instantaneous_phase_corrected

# %% [markdown]
# # Process experiments that use 100-micron spots

# %% [markdown]
# ### Phase tuning 230421
# #### mouse: P163
# #### experiment: random single spot stim with contra and ipsi occlusion
# #### spot size: 100 microns

# %% [markdown]
# ### Contra occlusion experiment

# %%
expt_ID = '230421'

datafile = [r'Z:\robin\expt_sets\pattern_stim\recordings\230421\2023-04-21_12-45-55\experiment1\recording1\sc\230421-001_bank1\230421-001_bank1.result-1.hdf5',
           r'Z:\robin\expt_sets\pattern_stim\recordings\230421\2023-04-21_12-45-55\experiment1\recording1\sc\230421-001_bank2\230421-001_bank2.result-1.hdf5']

mtrigger_file = r'Z:\robin\expt_sets\pattern_stim\recordings\230421\2023-04-21_12-45-55\experiment1\recording1\continuous\Rhythm_FPGA-100.0\230421_mtrigger.dat'

resp_phase_path = r'Z:\robin\expt_sets\pattern_stim\recordings\230421\2023-04-21_12-45-55\experiment1\recording1\continuous\Rhythm_FPGA-100.0\230421_breath.dat'

expt_metadata_path = r'Z:\robin\expt_sets\pattern_stim\metadata\230421\P163_2023_4_21_135647_fullexpt'

# %%
preprocess_spiking_data(expt_ID, datafile, mtrigger_file, expt_metadata_path, expt_category = 'contra', expt_type = 1)
# Out:
# 24000
# C:\Users\rmb55\virtual_environments\pattern-stim3\lib\site-packages\numpy\core\_asarray.py:171: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray.
#   return array(a, dtype, copy=False, order=order, subok=True)

# %%
resp_array, instantaneous_phase_corrected = preprocess_resp(expt_ID, resp_phase_path)

# %%
plt.figure(figsize = (7,7))
chunk = 1000
plt.plot(resp_array[200000*chunk:200000*(chunk+1)]/5000)
plt.plot(instantaneous_phase_corrected[200000*chunk:200000*(chunk+1)])
PGanalysis.axis_fixer(ratio = 1)

# %% [markdown]
# ### Ipsi occlusion experiment

# %%
expt_ID = '230421'

datafile = [r'Z:\robin\expt_sets\pattern_stim\recordings\230421\2023-04-21_12-45-55\experiment1\recording1\sc\230421-001_bank1\230421-001_bank1.result-1.hdf5',
           r'Z:\robin\expt_sets\pattern_stim\recordings\230421\2023-04-21_12-45-55\experiment1\recording1\sc\230421-001_bank2\230421-001_bank2.result-1.hdf5']

mtrigger_file = r'Z:\robin\expt_sets\pattern_stim\recordings\230421\2023-04-21_12-45-55\experiment1\recording1\continuous\Rhythm_FPGA-100.0\230421_mtrigger.dat'

resp_phase_path = r'Z:\robin\expt_sets\pattern_stim\recordings\230421\2023-04-21_12-45-55\experiment1\recording1\continuous\Rhythm_FPGA-100.0\230421_breath.dat'

expt_metadata_path = r'Z:\robin\expt_sets\pattern_stim\metadata\230421\P163_2023_4_21_153221_fullexpt'

# %%
preprocess_spiking_data(expt_ID, datafile, mtrigger_file, expt_metadata_path, expt_category = 'ipsi', expt_type = 2)

# %% [markdown]
# ### Phase tuning 230501
# #### mouse: P164
# #### experiment: random single spot stim with contra and ipsi occlusion
# #### spot size: 100 microns

# %% [markdown]
# ### Contra occlusion experiment

# %%
expt_ID = '230501'

datafile = [r'Z:\robin\expt_sets\pattern_stim\recordings\230501\2023-05-01_12-35-36\experiment1\recording1\sc\230501-001_bank1\230501-001_bank1.result-1.hdf5',
           r'Z:\robin\expt_sets\pattern_stim\recordings\230501\2023-05-01_12-35-36\experiment1\recording1\sc\230501-001_bank2\230501-001_bank2.result-1.hdf5']

mtrigger_file = r'Z:\robin\expt_sets\pattern_stim\recordings\230501\2023-05-01_12-35-36\experiment1\recording1\continuous\Rhythm_FPGA-100.0\230501_mtrigger.dat'

resp_phase_path = r'Z:\robin\expt_sets\pattern_stim\recordings\230501\2023-05-01_12-35-36\experiment1\recording1\continuous\Rhythm_FPGA-100.0\230501_breath.dat'

expt_metadata_path = r'Z:\robin\expt_sets\pattern_stim\metadata\230501\P164_2023_5_1_134634_fullexpt'

# %%
preprocess_spiking_data(expt_ID, datafile, mtrigger_file, expt_metadata_path, expt_category = 'contra', expt_type = 1)
# Out:
# 24000

# %%
resp_array, instantaneous_phase_corrected = preprocess_resp(expt_ID, resp_phase_path)

# %%
plt.figure(figsize = (7,7))
chunk = 1000
plt.plot(resp_array[200000*chunk:200000*(chunk+1)]/5000)
plt.plot(instantaneous_phase_corrected[200000*chunk:200000*(chunk+1)])
PGanalysis.axis_fixer(ratio = 1)

# %% [markdown]
# ### Ipsi occlusion experiment

# %%
expt_ID = '230501'

datafile = [r'Z:\robin\expt_sets\pattern_stim\recordings\230501\2023-05-01_12-35-36\experiment1\recording1\sc\230501-001_bank1\230501-001_bank1.result-1.hdf5',
           r'Z:\robin\expt_sets\pattern_stim\recordings\230501\2023-05-01_12-35-36\experiment1\recording1\sc\230501-001_bank2\230501-001_bank2.result-1.hdf5']

mtrigger_file = r'Z:\robin\expt_sets\pattern_stim\recordings\230501\2023-05-01_12-35-36\experiment1\recording1\continuous\Rhythm_FPGA-100.0\230501_mtrigger.dat'

resp_phase_path = r'Z:\robin\expt_sets\pattern_stim\recordings\230501\2023-05-01_12-35-36\experiment1\recording1\continuous\Rhythm_FPGA-100.0\230501_breath.dat'

expt_metadata_path = r'Z:\robin\expt_sets\pattern_stim\metadata\230501\P164_2023_5_1_151833_fullexpt'

# %%
preprocess_spiking_data(expt_ID, datafile, mtrigger_file, expt_metadata_path, expt_category = 'ipsi', expt_type = 2)

# %% [markdown]
# ### Phase tuning 230509
# #### mouse: P165
# #### experiment: random single spot stim with contra and ipsi occlusion
# #### spot size: 100 microns

# %% [markdown]
# ### Contra occlusion experiment

# %%
expt_ID = '230509'

datafile = [r'Z:\robin\expt_sets\pattern_stim\recordings\230509\2023-05-09_13-18-25\experiment1\recording2\sc\230509-001_bank1\230509-001_bank1.result-1.hdf5',
           r'Z:\robin\expt_sets\pattern_stim\recordings\230509\2023-05-09_13-18-25\experiment1\recording2\sc\230509-001_bank2\230509-001_bank2.result-1.hdf5']

mtrigger_file = r'Z:\robin\expt_sets\pattern_stim\recordings\230509\2023-05-09_13-18-25\experiment1\recording2\continuous\Rhythm_FPGA-100.0\230509_mtrigger.dat'

resp_phase_path = r'Z:\robin\expt_sets\pattern_stim\recordings\230509\2023-05-09_13-18-25\experiment1\recording2\continuous\Rhythm_FPGA-100.0\230509_breath.dat'

expt_metadata_path = r'Z:\robin\expt_sets\pattern_stim\metadata\230509\P165_2023_5_9_142933_fullexpt'

# %%
preprocess_spiking_data(expt_ID, datafile, mtrigger_file, expt_metadata_path, expt_category = 'contra', expt_type = 1)
# Out:
# 24000

# %%
resp_array, instantaneous_phase_corrected = preprocess_resp(expt_ID, resp_phase_path)

# %%
plt.figure(figsize = (7,7))
chunk = 1000
plt.plot(resp_array[200000*chunk:200000*(chunk+1)]/5000)
plt.plot(instantaneous_phase_corrected[200000*chunk:200000*(chunk+1)])
PGanalysis.axis_fixer(ratio = 1)

# %% [markdown]
# ### Ipsi occlusion experiment

# %%
expt_ID = '230509'

datafile = [r'Z:\robin\expt_sets\pattern_stim\recordings\230509\2023-05-09_13-18-25\experiment1\recording2\sc\230509-001_bank1\230509-001_bank1.result-1.hdf5',
           r'Z:\robin\expt_sets\pattern_stim\recordings\230509\2023-05-09_13-18-25\experiment1\recording2\sc\230509-001_bank2\230509-001_bank2.result-1.hdf5']

mtrigger_file = r'Z:\robin\expt_sets\pattern_stim\recordings\230509\2023-05-09_13-18-25\experiment1\recording2\continuous\Rhythm_FPGA-100.0\230509_mtrigger.dat'

resp_phase_path = r'Z:\robin\expt_sets\pattern_stim\recordings\230509\2023-05-09_13-18-25\experiment1\recording2\continuous\Rhythm_FPGA-100.0\230509_breath.dat'

expt_metadata_path = r'Z:\robin\expt_sets\pattern_stim\metadata\230509\P165_2023_5_9_155750_fullexpt'

# %%
preprocess_spiking_data(expt_ID, datafile, mtrigger_file, expt_metadata_path, expt_category = 'ipsi', expt_type = 2)

# %% [markdown]
# ### Phase tuning 230622
# #### mouse: P167
# #### experiment: random single spot stim with contra and ipsi occlusion
# #### spot size: 100 microns

# %% [markdown]
# ### Contra occlusion experiment

# %%
expt_ID = '230622'

datafile = [r'Z:\robin\expt_sets\pattern_stim\recordings\230622\2023-06-22_13-00-06\experiment1\recording1\sc\230622-001_bank1\230622-001_bank1.result-1.hdf5',
           r'Z:\robin\expt_sets\pattern_stim\recordings\230622\2023-06-22_13-00-06\experiment1\recording1\sc\230622-001_bank2\230622-001_bank2.result-1.hdf5']

mtrigger_file = r'Z:\robin\expt_sets\pattern_stim\recordings\230622\2023-06-22_13-00-06\experiment1\recording1\continuous\Rhythm_FPGA-100.0\230622_mtrigger.dat'

resp_phase_path = r'Z:\robin\expt_sets\pattern_stim\recordings\230622\2023-06-22_13-00-06\experiment1\recording1\continuous\Rhythm_FPGA-100.0\230622_breath.dat'

expt_metadata_path = r'Z:\robin\expt_sets\pattern_stim\metadata\230622\P167_2023_6_22_141020_fullexpt'

# %%
preprocess_spiking_data(expt_ID, datafile, mtrigger_file, expt_metadata_path, expt_category = 'contra', expt_type = 1)
# Out:
# 24000

# %%
resp_array, instantaneous_phase_corrected = preprocess_resp(expt_ID, resp_phase_path)

# %%
plt.figure(figsize = (7,7))
chunk = 1000
plt.plot(resp_array[200000*chunk:200000*(chunk+1)]/5000)
plt.plot(instantaneous_phase_corrected[200000*chunk:200000*(chunk+1)])
PGanalysis.axis_fixer(ratio = 1)

# %% [markdown]
# ### Ipsi occlusion experiment

# %%
expt_ID = '230622'

datafile = [r'Z:\robin\expt_sets\pattern_stim\recordings\230622\2023-06-22_13-00-06\experiment1\recording1\sc\230622-001_bank1\230622-001_bank1.result-1.hdf5',
           r'Z:\robin\expt_sets\pattern_stim\recordings\230622\2023-06-22_13-00-06\experiment1\recording1\sc\230622-001_bank2\230622-001_bank2.result-1.hdf5']

mtrigger_file = r'Z:\robin\expt_sets\pattern_stim\recordings\230622\2023-06-22_13-00-06\experiment1\recording1\continuous\Rhythm_FPGA-100.0\230622_mtrigger.dat'

resp_phase_path = r'Z:\robin\expt_sets\pattern_stim\recordings\230622\2023-06-22_13-00-06\experiment1\recording1\continuous\Rhythm_FPGA-100.0\230622_breath.dat'

expt_metadata_path = r'Z:\robin\expt_sets\pattern_stim\metadata\230622\P167_2023_6_22_153924_fullexpt'

# %%
preprocess_spiking_data(expt_ID, datafile, mtrigger_file, expt_metadata_path, expt_category = 'ipsi', expt_type = 2)

# %% [markdown]
# ### Phase tuning 230724
# #### mouse: P168
# #### experiment: random single spot stim with contra and ipsi occlusion
# #### spot size: 100 microns

# %% [markdown]
# ### Contra occlusion experiment

# %%
expt_ID = '230724'

datafile = [r'Z:\robin\expt_sets\pattern_stim\recordings\230724\2023-07-24_12-07-08\experiment1\recording2\sc\230724-001_bank1\230724-001_bank1.result-1.hdf5',
           r'Z:\robin\expt_sets\pattern_stim\recordings\230724\2023-07-24_12-07-08\experiment1\recording2\sc\230724-001_bank2\230724-001_bank2.result-1.hdf5']

mtrigger_file = r'Z:\robin\expt_sets\pattern_stim\recordings\230724\2023-07-24_12-07-08\experiment1\recording2\continuous\Rhythm_FPGA-100.0\230724_mtrigger.dat'

resp_phase_path = r'Z:\robin\expt_sets\pattern_stim\recordings\230724\2023-07-24_12-07-08\experiment1\recording2\continuous\Rhythm_FPGA-100.0\230724_breath.dat'

expt_metadata_path = r'Z:\robin\expt_sets\pattern_stim\metadata\230724\P168_2023_7_24_132056_fullexpt'

# %%
preprocess_spiking_data(expt_ID, datafile, mtrigger_file, expt_metadata_path, expt_category = 'contra', expt_type = 1)
# Out:
# 24000

# %%
resp_array, instantaneous_phase_corrected = preprocess_resp(expt_ID, resp_phase_path)

# %%
plt.figure(figsize = (7,7))
chunk = 1000
plt.plot(resp_array[200000*chunk:200000*(chunk+1)]/5000)
plt.plot(instantaneous_phase_corrected[200000*chunk:200000*(chunk+1)])
PGanalysis.axis_fixer(ratio = 1)

# %% [markdown]
# ### Ipsi occlusion experiment

# %%
expt_ID = '230724'

datafile = [r'Z:\robin\expt_sets\pattern_stim\recordings\230724\2023-07-24_12-07-08\experiment1\recording2\sc\230724-001_bank1\230724-001_bank1.result-1.hdf5',
           r'Z:\robin\expt_sets\pattern_stim\recordings\230724\2023-07-24_12-07-08\experiment1\recording2\sc\230724-001_bank2\230724-001_bank2.result-1.hdf5']

mtrigger_file = r'Z:\robin\expt_sets\pattern_stim\recordings\230724\2023-07-24_12-07-08\experiment1\recording2\continuous\Rhythm_FPGA-100.0\230724_mtrigger.dat'

resp_phase_path = r'Z:\robin\expt_sets\pattern_stim\recordings\230724\2023-07-24_12-07-08\experiment1\recording2\continuous\Rhythm_FPGA-100.0\230724_breath.dat'

expt_metadata_path = r'Z:\robin\expt_sets\pattern_stim\metadata\230724\P168_2023_7_24_145746_fullexpt'

# %%
preprocess_spiking_data(expt_ID, datafile, mtrigger_file, expt_metadata_path, expt_category = 'ipsi', expt_type = 2)

# %% [markdown]
# ### Phase tuning 230731
# #### mouse: P169
# #### experiment: random single spot stim with contra and ipsi occlusion
# #### spot size: 100 microns

# %% [markdown]
# ### Contra occlusion experiment

# %%
expt_ID = '230731'

datafile = [r'Z:\robin\expt_sets\pattern_stim\recordings\230731\2023-07-31_11-26-20\experiment1\recording2\sc\230731-001_bank1\230731-001_bank1.result-1.hdf5',
           r'Z:\robin\expt_sets\pattern_stim\recordings\230731\2023-07-31_11-26-20\experiment1\recording2\sc\230731-001_bank2\230731-001_bank2.result-1.hdf5']

mtrigger_file = r'Z:\robin\expt_sets\pattern_stim\recordings\230731\2023-07-31_11-26-20\experiment1\recording2\continuous\Rhythm_FPGA-100.0\230731_mtrigger.dat'

resp_phase_path = r'Z:\robin\expt_sets\pattern_stim\recordings\230731\2023-07-31_11-26-20\experiment1\recording2\continuous\Rhythm_FPGA-100.0\230731_breath.dat'

expt_metadata_path = r'Z:\robin\expt_sets\pattern_stim\metadata\230731\P169_2023_7_31_123946_fullexpt'

# %%
preprocess_spiking_data(expt_ID, datafile, mtrigger_file, expt_metadata_path, expt_category = 'contra', expt_type = 1)
# Out:
# 24000

# %%
resp_array, instantaneous_phase_corrected = preprocess_resp(expt_ID, resp_phase_path)

# %%
plt.figure(figsize = (7,7))
chunk = 1000
plt.plot(resp_array[200000*chunk:200000*(chunk+1)]/5000)
plt.plot(instantaneous_phase_corrected[200000*chunk:200000*(chunk+1)])
PGanalysis.axis_fixer(ratio = 1)

# %% [markdown]
# ### Ispi occlusion experiment

# %%
expt_ID = '230731'

datafile = [r'Z:\robin\expt_sets\pattern_stim\recordings\230731\2023-07-31_11-26-20\experiment1\recording2\sc\230731-001_bank1\230731-001_bank1.result-1.hdf5',
           r'Z:\robin\expt_sets\pattern_stim\recordings\230731\2023-07-31_11-26-20\experiment1\recording2\sc\230731-001_bank2\230731-001_bank2.result-1.hdf5']

mtrigger_file = r'Z:\robin\expt_sets\pattern_stim\recordings\230731\2023-07-31_11-26-20\experiment1\recording2\continuous\Rhythm_FPGA-100.0\230731_mtrigger.dat'

resp_phase_path = r'Z:\robin\expt_sets\pattern_stim\recordings\230731\2023-07-31_11-26-20\experiment1\recording2\continuous\Rhythm_FPGA-100.0\230731_breath.dat'


expt_metadata_path = r'Z:\robin\expt_sets\pattern_stim\metadata\230731\P169_2023_7_31_141149_fullexpt'

# %%
preprocess_spiking_data(expt_ID, datafile, mtrigger_file, expt_metadata_path, expt_category = 'ipsi', expt_type = 2)
